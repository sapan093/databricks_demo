-- %%
:param_1 create table Employee
(
  Id int,
  name string,
  Salary float
)


Insert into Employee
values (1,'sapan', 100.90)

Insert into Employee
values (1,'Piyush', 1009.99)


select * from employee


DESCRIBE detail employee

restore table Employee TO VERSION as of 2

Describe history employee


update employee
set salary = salary+ 100
where name ='Piyush'

Describe history employee
describe detail employee

optimize employee
zorder by id

select * from employee

select * from employee@v2
select * from employee@v1
